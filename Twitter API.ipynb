# %% [markdown]
# # Filtering specific words using Twitter's API
#
# For the following analysis we will import the tweepy library on Python.

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %% [markdown]
# Having previously signed up with your twitter account on www.apps.twitter.com and after creating an application,
# now we will use the access tokens provided by Twitter under the tab called 'Keys and Access Tokens'.

# %%
consumer_key = 'cdr9zMvyRl5pzMPvs8sHe8AVF'
consumer_secret = 'ac3C3JX26deOBhd1LM0qUnEXhpfDU3L4wS77pVDbHzhfdQ8nqg'
access_token = '948883182803406848-L3IF9AJZN2TucudYnMdoenrz4qxarCg'
access_token_secret = 'jU8akfpWI2yFKkAxEwr9IQP9ah4hhMERnwkeiA7jH59km'

class StdOutListener(StreamListener):

    def on_data(self, data):
        print (data)
        return True

    def on_error(self, status):
        print (status)

if __name__ == '__main__':

    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    stream = Stream(auth, l)

# %% [markdown]
# Now enter the words that you want to filter in tweets. Here it is an example filtering the word Bilbao.
# You can also filter more words adding a comma after Bilbao and entering a new word.
# Keep in mind that the tweets you filter will either have one, two or either all of the words you add.

# %%
stream.filter(track=['Bilbao'])
# Out:
# {"created_at":"Mon Mar 19 14:50:38 +0000 2018","id":975746374460469248,"id_str":"975746374460469248","text":"RT @fcbarcelona_fra: \ud83d\udd35\ud83d\udd34\ud83c\udfa5 Inarr\u00eatable, le Pichichi Leo #Messi a  encore frapp\u00e9 hier contre Bilbao ! Zoom sur sa performance ! #Bar\u00e7aAthletic\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":3151241363,"id_str":"3151241363","name":"GermainFripeL30\ud83c\udfdf\u26bd","screen_name":"mananga_serge","location":null,"url":null,"description":"#L30Messi\ud83d\udc51\ud83c\udf1f\n#For\u00e7aBar\u00e7a\ud83c\udfdf\u26bd\ud83d\udcaa\n#wwe\u2764\ud83d\udcaa\n#DBS\ud83d\udd25\ud83d\udcaa\ud83d\ude0d\u2764\ud83d\udcaf\ud83d\udc4c  \n#TWD\ud83d\udc80\ud83d\udd2b\ud83d\udc95\n#FWD\ud83d\
# ...

# %% [markdown]
# # Conclusion
#
# The data returned by the Twitter API comes in json format and unstructured.
# I had to stop running the code because if not this would be running non stop.
# The text returned by our code should be then cleaned and analyzed with the appropriate libraries for Sentiment Analysis.
# I personally recommend nltk, a Natural Language Processing library for Python.
